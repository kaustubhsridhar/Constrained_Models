# %%
from utils import plot_gif_at_rest, plot_at_rest
S=0
N=20
plot_gif_at_rest(mems=[500, 1000, 2500], seed=S, N=N, aug=False)
plot_gif_at_rest(mems=[], seed=S, N=N, aug=False)
# Out:
# /home/ksridhar/Constrained_World_Models/scripts/utils.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(num)

# %%
from utils import plot_gif_at_rest, plot_at_rest
S=1
N=20
plot_at_rest(mems=[500, 1000, 2500], seed=S, N=N, aug=False)
plot_at_rest(mems=[], seed=S, N=N, aug=False)
