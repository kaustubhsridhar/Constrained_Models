# %%
# from utils import plotbars
# plotbars(f'Carla15k15k', aug=False, mems=[500, 1000, 2500], seeds=[0, 1, 2], unnorm=True, boundscheduling=False)

# %%
from utils import plot
plot(f'Carla15k15k', aug=False, mems=[500, 1000, 2500], seeds=[0, 1, 2], unnorm=True, boundscheduling=False)
# Out:
# logs_today/Carla15k15k_Constrained_500_1_0delta_seed0.log
# logs_today/Carla15k15k_Constrained_1000_1_0delta_seed0.log
# logs_today/Carla15k15k_Constrained_2500_1_0delta_seed0.log
# logs_today/Carla15k15k_Constrained_500_1_0delta_seed1.log
# logs_today/Carla15k15k_Constrained_1000_1_0delta_seed1.log
# logs_today/Carla15k15k_Constrained_2500_1_0delta_seed1.log
# logs_today/Carla15k15k_Constrained_500_1_0delta_seed2.log
# logs_today/Carla15k15k_Constrained_1000_1_0delta_seed2.log
# logs_today/Carla15k15k_Constrained_2500_1_0delta_seed2.log
# 7425 7425 7425
# 7425 7425 7425
# 7425 7425 7425
# 7425 7425 7425
# 7425 7425 7425
# 7425 7425 7425
# 7425 7425 7425
