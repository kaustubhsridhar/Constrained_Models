# %%
from utils import plotbars
plotbars(f'AP', aug=False, mems=[1000, 1500, 2000], seeds=[0, 100, 200], unnorm=True, boundscheduling=True) # , 100, 200
# Out:
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed200.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed200.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed200.log

# %%
from utils import plot
plot(f'AP', aug=False, mems=[1000, 1500, 2000], seeds=[0, 100, 200], unnorm=True, boundscheduling=True) # , 100, 200
# Out:
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed0.log
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed100.log
# logs_today/APBoundScheduling_Constrained_1000_1_0delta_seed200.log
# logs_today/APBoundScheduling_Constrained_1500_1_0delta_seed200.log
# logs_today/APBoundScheduling_Constrained_2000_1_0delta_seed200.log
# 7500 7500 7500
# 7500 7500 7500
# 7500 7500 7500
# 7500 7500 7500
# 7500 7500 7500
# 7500 7500 7500
# 7500 7500 7500
