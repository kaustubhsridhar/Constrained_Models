# %%
from utils import plotbars
plotbars(f'DronesGndDragDwData', aug=False, mems=[800, 1000, 2000], seeds=[0, 1, 2], unnorm=True, boundscheduling=False) # , 1, 2
# Out:
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed2.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed2.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed2.log
# 2 Avg Approx Loss $D$ Lagrangian 250
# 2 Avg Approx Loss $D$ Lagrangian 350
# 2 Avg Approx Loss $D$ Constrained_800 250
# 2 Avg Approx Loss $D$ Constrained_800 350
# 2 Avg Approx Loss $D$ Constrained_1000 250
# 2 Avg Approx Loss $D$ Constrained_1000 350
# 2 Avg Approx Loss $D$ Constrained_2000 250
# 2 Avg Approx Loss $D$ Constrained_2000 350
# ...

# %%
from utils import plot
plot(f'DronesGndDragDwData', aug=False, mems=[800, 1000, 2000], seeds=[0, 1, 2], unnorm=True, boundscheduling=False) # , 1, 2
# Out:
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed0.log
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed1.log
# logs_today/DronesGndDragDwData_Constrained_800_1_0delta_seed2.log
# logs_today/DronesGndDragDwData_Constrained_1000_1_0delta_seed2.log
# logs_today/DronesGndDragDwData_Constrained_2000_1_0delta_seed2.log
# 6039 6039 6039
# 6005 6005 6005
# 6005 6005 6005
# 6006 6006 6006
# 6039 6039 6039
# 6005 6005 6005
# 6005 6005 6005
